# %%
import json
import numpy
import matplotlib.pyplot as plt
sqLen = 10
lennnn = 0

# %%
with open('newdata.json') as f:
    data = json.load(f)
with open('temp1.json') as f:
    temp1 = json.load(f)
# with open('validateDataPredict.json') as f:
#     validateDataPredict = json.load(f)
    
# trainData = []
# for i in trainDataPredict:
#     trainData.append(i)
    
# validateData = []
# for i in validateDataPredict:
#     validateData.append(i)

plt.figure(figsize=(20,5))
# plt.plot(numpy.linspace(0, len(data), len(data)), data)
plt.plot(numpy.linspace(0 + lennnn, 400 + lennnn, 400), data[0+ lennnn:400+ lennnn])
plt.plot(numpy.linspace(0 + sqLen + lennnn, 400 + sqLen + lennnn, 400), temp1[0+ lennnn:400+ lennnn])
# plt.plot(numpy.linspace(0, len(trainData), len(trainData)), trainData)
# plt.plot(numpy.linspace(len(trainData), len(trainData)+len(validateData), len(validateData)), validateData)
plt.show()

# %%
with open('newdata.json') as f:
    data = json.load(f)
with open('temp2.json') as f:
    temp2 = json.load(f)

plt.figure(figsize=(20,5))
plt.plot(numpy.linspace(0, 400, 400), data[0:400])
plt.plot(numpy.linspace(1 + sqLen, 401 + sqLen, 400), temp2[0:400])
plt.show()

# %%
with open('newdata.json') as f:
    data = json.load(f)
with open('temp3.json') as f:
    temp3 = json.load(f)

plt.figure(figsize=(20,5))
plt.plot(numpy.linspace(0, 400, 400), data[0:400])
plt.plot(numpy.linspace(2 + sqLen, 402 + sqLen, 400), temp3[0:400])
plt.show()
